# %%
running = True
while running:
    print('Still running')
    for i in range(19):
        print(i, running)
        if i == 5:
            running = False
# Out:
# Still running
# 0 True
# 1 True
# 2 True
# 3 True
# 4 True
# 5 True
# 6 False
# 7 False
# 8 False
# 9 False
# 10 False
# 11 False
# 12 False
# 13 False
# 14 False
# 15 False
# 16 False
# 17 False
# 18 False

# %%
import pandas as pd

df = pd.read_csv('calibration/results/2023_02_02-10_11_10-binary_calibration.csv')

# %%
import matplotlib.pyplot as plt

_, ax = plt.subplots(figsize=(8, 8))

ax.scatter(df['x'], df['y'])
ax.set_xlim((-10, 10))
ax.set_ylim((-8, 8))
plt.show()

# %%
import pandas as pd

df = pd.read_csv('calibration/results/2023_02_02-10_22_07-ternary_calibration.csv')

# %%
import matplotlib.pyplot as plt

_, ax = plt.subplots(figsize=(8, 8))

ax.scatter(df['x'], df['y'])
ax.set_xlim((-10, 10))
ax.set_ylim((-8, 8))
plt.show()

# %%
import pickle

with open('calibration/results/2023_02_02-10_22_07-ternary_calibration.pkl', 'rb') as f:
    data = pickle.load(f)

# %%
data
# Out:
# {'global': {'window_width': 1280,
#   'window_height': 720,
#   'bg_color': [19, 19, 19],
#   'exp_duration': 0.2},
#  'monitor': {'horizontal_pixel_resolution': 1980,
#   'monitor_width': 400,
#   'viewing_distance': 1000},
#  'fixation': {'min_duration': 2, 'max_duration': 4},
#  'saccade': {'min_duration': 0.06, 'max_duration': 0.15},
#  'pursuit': {'min_duration': 1,
#   'max_duration': 3,
#   'min_vel': 100,
#   'max_vel': 300},
#  'movements': [{'type': 'fixation',
#    'start_pos': array([627. , 347.5]),
#    'end_pos': array([627. , 347.5]),
#    'amplitude': 0,
#    'velocity': array([0, 0]),
#    'duration': 2.0326514036067147,
#    'timestamps': [0,
#     10,
#     21,
#     31,
#     41,
#     52,
#     63,
#     73,
#     83,
#     94,
#     105,
#     115,
#     126,
#     137,
#     148,
#     158,
#     168,
#     178,
#     189,
#     200,
#     210,
#     220,
#     230,
#     240,
#     250,
#     260,
#     270,
#     280,
#     290,
#     300,
#     310,
# ...
